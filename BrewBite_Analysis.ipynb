# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # LOAD DATA

# %%
df = pd.read_csv("C:\\Users\\Vansh Sharma\\Documents\\S.csv")
df.head()
# Out:
#   record_id outlet_id                    outlet_name       area   zone  \
# 0    R10000    OUT101  BrewBite Jayanagar Standalone  Jayanagar  South
# 1    R10001    OUT101  BrewBite Jayanagar Standalone  Jayanagar  South
# 2    R10002    OUT101  BrewBite Jayanagar Standalone  Jayanagar  South
# 3    R10003    OUT101  BrewBite Jayanagar Standalone  Jayanagar  South
# 4    R10004    OUT101  BrewBite Jayanagar Standalone  Jayanagar  South
#
#   store_format  store_size_sqft  opening_year    month  footfall  ...  \
# 0   Standalone              979          2022  2023-01      5652  ...
# 1   Standalone              979          2022  2023-02      5915  ...
# 2   Standalone              979          2022  2023-03      6870  ...
# 3   Standalone              979          2022  2023-04      7016  ...
# 4   Standalone              979          2022  2023-05      8028  ...
#
#    avg_order_value  revenue    cogs   rent  salaries  marketing_spend  \
# 0              228   683550  221480  83200     92700            40111
# 1              266   881480  277421  83200     83000            29340
# 2              237   843640  274419  83200     97900            46531
# 3              222   757080  231879  83200    100800            49846
# 4              189   808460  257207  83200     93600            33210
#
#    utilities  total_cost  profit  profit_margin_pct
# 0      45200      482691  200859               29.4
# 1      45500      518461  363019               41.2
# 2      41100      543150  300490               35.6
# 3      38800      504525  252555               33.4
# 4      31700      498917  309543               38.3
#
# [5 rows x 21 columns]

# %% [markdown]
# # Data Cleaning

# %%
df.describe()
# Out:
#        store_size_sqft  opening_year      footfall        orders  \
# count      1000.000000   1000.000000   1000.000000   1000.000000
# mean        924.860000   2021.560000   6451.725000   3996.511000
# std         350.109093      1.283763   2584.920495   1670.761843
# min         215.000000   2019.000000   1763.000000    938.000000
# 25%         781.000000   2021.000000   4616.000000   2825.750000
# 50%         944.000000   2022.000000   6011.500000   3681.000000
# 75%        1154.000000   2023.000000   8338.250000   5182.500000
# max        1684.000000   2023.000000  16735.000000  10731.000000
#
#        avg_order_value       revenue          cogs           rent  \
# count      1000.000000  1.000000e+03  1.000000e+03    1000.000000
# mean        248.493000  1.008827e+06  3.227688e+05   94440.000000
# std          29.818503  4.868814e+05  1.571077e+05   65701.944762
# min         175.000000  2.232200e+05  7.287700e+04    6800.000000
# 25%         228.000000  6.612950e+05  2.120268e+05   49900.000000
# 50%         246.000000  9.112550e+05  2.851410e+05   81050.000000
# 75%         267.000000  1.307578e+06  4.188105e+05  123200.000000
# max         365.000000  3.142090e+06  1.015058e+06  280900.000000
#
#             salaries  marketing_spend     utilities    total_cost  \
# count    1000.000000      1000.000000   1000.000000  1.000000e+03
# mean    91209.300000     50103.111000  41120.000000  5.996412e+05
# std     36743.352562     28638.931131  11066.124847  2.457355e+05
# min     16500.000000      6591.000000  16000.000000  1.868320e+05
# 25%     71650.000000     30040.000000  33375.000000  4.129598e+05
# 50%     92300.000000     44051.500000  41800.000000  5.385110e+05
# 75%    113750.000000     62807.500000  48600.000000  7.276965e+05
# max    193000.000000    224043.000000  71300.000000  1.713601e+06
#
#              profit  profit_margin_pct
# count  1.000000e+03        1000.000000
# mean   4.091859e+05          36.136100
# std    2.834277e+05          16.663934
# min   -1.114680e+05         -35.100000
# 25%    1.963692e+05          28.875000
# 50%    3.768590e+05          38.900000
# 75%    5.761975e+05          48.500000
# max    1.699058e+06          62.700000

# %%
df.isnull().sum()
# Out:
# record_id            0
# outlet_id            0
# outlet_name          0
# area                 0
# zone                 0
# store_format         0
# store_size_sqft      0
# opening_year         0
# month                0
# footfall             0
# orders               0
# avg_order_value      0
# revenue              0
# cogs                 0
# rent                 0
# salaries             0
# marketing_spend      0
# utilities            0
# total_cost           0
# profit               0
# profit_margin_pct    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        store_size_sqft  opening_year      footfall        orders  \
# count      1000.000000   1000.000000   1000.000000   1000.000000
# mean        924.860000   2021.560000   6451.725000   3996.511000
# std         350.109093      1.283763   2584.920495   1670.761843
# min         215.000000   2019.000000   1763.000000    938.000000
# 25%         781.000000   2021.000000   4616.000000   2825.750000
# 50%         944.000000   2022.000000   6011.500000   3681.000000
# 75%        1154.000000   2023.000000   8338.250000   5182.500000
# max        1684.000000   2023.000000  16735.000000  10731.000000
#
#        avg_order_value       revenue          cogs           rent  \
# count      1000.000000  1.000000e+03  1.000000e+03    1000.000000
# mean        248.493000  1.008827e+06  3.227688e+05   94440.000000
# std          29.818503  4.868814e+05  1.571077e+05   65701.944762
# min         175.000000  2.232200e+05  7.287700e+04    6800.000000
# 25%         228.000000  6.612950e+05  2.120268e+05   49900.000000
# 50%         246.000000  9.112550e+05  2.851410e+05   81050.000000
# 75%         267.000000  1.307578e+06  4.188105e+05  123200.000000
# max         365.000000  3.142090e+06  1.015058e+06  280900.000000
#
#             salaries  marketing_spend     utilities    total_cost  \
# count    1000.000000      1000.000000   1000.000000  1.000000e+03
# mean    91209.300000     50103.111000  41120.000000  5.996412e+05
# std     36743.352562     28638.931131  11066.124847  2.457355e+05
# min     16500.000000      6591.000000  16000.000000  1.868320e+05
# 25%     71650.000000     30040.000000  33375.000000  4.129598e+05
# 50%     92300.000000     44051.500000  41800.000000  5.385110e+05
# 75%    113750.000000     62807.500000  48600.000000  7.276965e+05
# max    193000.000000    224043.000000  71300.000000  1.713601e+06
#
#              profit  profit_margin_pct
# count  1.000000e+03        1000.000000
# mean   4.091859e+05          36.136100
# std    2.834277e+05          16.663934
# min   -1.114680e+05         -35.100000
# 25%    1.963692e+05          28.875000
# 50%    3.768590e+05          38.900000
# 75%    5.761975e+05          48.500000
# max    1.699058e+06          62.700000

# %%
df.dtypes
# Out:
# record_id             object
# outlet_id             object
# outlet_name           object
# area                  object
# zone                  object
# store_format          object
# store_size_sqft        int64
# opening_year           int64
# month                 object
# footfall               int64
# orders                 int64
# avg_order_value        int64
# revenue                int64
# cogs                   int64
# rent                   int64
# salaries               int64
# marketing_spend        int64
# utilities              int64
# total_cost             int64
# profit                 int64
# profit_margin_pct    float64
# dtype: object

# %% [markdown]
# # Feature Engineering

# %%
df["month"]=pd.to_datetime(df["month"])

# %%
df["Year"]=df["month"].dt.year

df["Month"]=df["month"].dt.month_name()

df["Revenue_per_Order"]=df["revenue"]/df["orders"]

df["Cost_per_Order"]=df["total_cost"]/df["orders"]

# %% [markdown]
# # KPIs

# %%
print("="*60)

print("BREWBITE KPI DASHBOARD")

print("="*60)

print(f"Total Revenue      : ₹{df['revenue'].sum():,.0f}")

print(f"Total Profit       : ₹{df['profit'].sum():,.0f}")

print(f"Total Orders       : {df['orders'].sum():,}")

print(f"Total Footfall     : {df['footfall'].sum():,}")

print(f"Average Order Value: ₹{df['avg_order_value'].mean():.2f}")

print(f"Average Margin     : {df['profit_margin_pct'].mean():.2f}%")
# Out:
# ============================================================
# BREWBITE KPI DASHBOARD
# ============================================================
# Total Revenue      : ₹1,008,827,150
# Total Profit       : ₹409,185,903
# Total Orders       : 3,996,511
# Total Footfall     : 6,451,725
# Average Order Value: ₹248.49
# Average Margin     : 36.14%

# %%
outlet=df.groupby("outlet_name").agg({

"revenue":"sum",

"profit":"sum",

"orders":"sum",

"footfall":"sum",

"profit_margin_pct":"mean"

})

outlet
# Out:
#                                     revenue    profit  orders  footfall  \
# outlet_name
# BrewBite BTM Layout High           42451200  14692204  175613    282729
# BrewBite BTM Layout Standalone     14838000   5999150   64379    101932
# BrewBite Banashankari High         24208290   6752511  102127    162067
# BrewBite Banashankari Standalone   22218960   6835492   91235    149216
# BrewBite Bellandur Food            51822830  28974284  215622    337017
# BrewBite Domlur Food               24296360  12862038   85773    143073
# BrewBite Domlur Standalone         37498960  18782817  131622    211378
# BrewBite Electronic City High      15134410   4539740   63977    103428
# BrewBite HSR Layout Mall           45775130  19388878  158370    255311
# BrewBite Indiranagar Standalone    28828540  13959592  103065    169781
# BrewBite JP Nagar Food             16420640   8245985   68524    109572
# BrewBite JP Nagar High             45705650  17197235  190408    302493
# BrewBite JP Nagar Standalone       69955910  28381199  290940    468993
# BrewBite Jayanagar Mall            16526730   1139985   71907    114321
# BrewBite Jayanagar Standalone      42100320  18099080  176308    293019
# BrewBite KR Puram Mall             16318600   3668090   71673    116286
# BrewBite Koramangala High          30929120  11492973  112213    179873
# BrewBite Koramangala Kiosk         28950670  17153396  103721    166860
# BrewBite Koramangala Mall          30222770   9484127  108207    174372
# BrewBite MG Road High              38283270  16950520  143472    227097
# BrewBite MG Road Mall              36128700  14143662  130917    208927
# BrewBite MG Road Standalone        76061590  33271914  274721    439349
# BrewBite Malleshwaram Standalone   14005160   4314785   57939     95729
# BrewBite Marathahalli Food         36372190  18752355  151086    251879
# BrewBite Marathahalli Mall         27347960   9511126  112489    183423
# BrewBite Marathahalli Standalone   10845730   3056763   45291     72446
# BrewBite Rajajinagar High          20342420   3276536   85749    138945
# BrewBite Sarjapur Road Kiosk       18004790  10359088   76118    123901
# BrewBite Sarjapur Road Standalone   8023030    624485   33953     52942
# BrewBite Whitefield High           25468430  10521470  106157    169310
# BrewBite Yelahanka Food            16910520   9052133   69180    113721
# BrewBite Yelahanka High             9077800    846785   37924     63956
# BrewBite Yelahanka Kiosk           12073680   6564046   49672     83246
# BrewBite Yelahanka Mall            21743050   7496559   91460    146128
# BrewBite Yeshwanthpur Food         16896620   8960276   71315    119176
# BrewBite Yeshwanthpur Standalone   17039120   3834624   73384    119829
#
#                                    profit_margin_pct
# outlet_name
# BrewBite BTM Layout High                   32.147500
# BrewBite BTM Layout Standalone             39.600000
# BrewBite Banashankari High                 25.657500
# BrewBite Banashankari Standalone           26.990000
# BrewBite Bellandur Food                    55.605000
# BrewBite Domlur Food                       52.165000
# BrewBite Domlur Standalone                 49.860000
# BrewBite Electronic City High              29.325000
# BrewBite HSR Layout Mall                   41.440000
# BrewBite Indiranagar Standalone            47.950000
# BrewBite JP Nagar Food                     49.790000
# BrewBite JP Nagar High                     36.755000
# BrewBite JP Nagar Standalone               38.975000
# BrewBite Jayanagar Mall                     3.645000
# BrewBite Jayanagar Standalone              42.287500
# BrewBite KR Puram Mall                     21.855000
# BrewBite Koramangala High                  36.895000
# BrewBite Koramangala Kiosk                 59.015000
# BrewBite Koramangala Mall                  30.395000
# BrewBite MG Road High                      43.430000
# BrewBite MG Road Mall                      38.850000
# BrewBite MG Road Standalone                40.043333
# BrewBite Malleshwaram Standalone           29.825000
# BrewBite Marathahalli Food                 50.995000
# BrewBite Marathahalli Mall                 34.135000
# BrewBite Marathahalli Standalone           24.870000
# BrewBite Rajajinagar High                   9.172500
# BrewBite Sarjapur Road Kiosk               57.355000
# BrewBite Sarjapur Road Standalone           4.055000
# BrewBite Whitefield High                   40.795000
# BrewBite Yelahanka Food                    53.070000
# BrewBite Yelahanka High                     4.810000
# BrewBite Yelahanka Kiosk                   54.090000
# BrewBite Yelahanka Mall                    33.865000
# BrewBite Yeshwanthpur Food                 52.770000
# BrewBite Yeshwanthpur Standalone           18.850000

# %% [markdown]
# # Visualization

# %%
monthly=df.groupby("month")["revenue"].sum()

plt.figure(figsize=(12,5))

plt.plot(monthly.index,
         monthly.values,
         linewidth=3,
         marker="o")

plt.title("Monthly Revenue Trend",fontsize=16)

plt.grid(alpha=.3)

plt.show()

# %%
profit=df.groupby("month")["profit"].sum()

plt.figure(figsize=(12,5))

plt.plot(profit.index,
         profit.values,
         linewidth=3,
         marker="o")

plt.title("Monthly Profit Trend",fontsize=16)

plt.show()

# %%
revenue=df.groupby("outlet_name")["revenue"].sum().sort_values()

plt.figure(figsize=(12,6))

plt.barh(revenue.index,
         revenue.values)

plt.title("Revenue by Outlet")

plt.show()

# %%
profit=df.groupby("outlet_name")["profit"].sum().sort_values()

plt.figure(figsize=(12,6))

plt.barh(profit.index,
         profit.values)

plt.title("Profit by Outlet")

plt.show()

# %%
area=df.groupby("area")["revenue"].sum()

plt.figure(figsize=(10,5))

plt.bar(area.index,
        area.values)

plt.xticks(rotation=45)

plt.title("Revenue by Area")

plt.show()

# %%
zone=df.groupby("zone")["revenue"].sum()

plt.figure(figsize=(8,5))

plt.pie(zone.values,
        labels=zone.index,
        autopct="%1.1f%%")

plt.title("Revenue Share by Zone")

plt.show()

# %%
store=df.groupby("store_format")["profit"].sum()

plt.figure(figsize=(8,5))

plt.bar(store.index,
        store.values)

plt.title("Profit by Store Format")

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["footfall"],
            df["orders"])

plt.xlabel("Footfall")

plt.ylabel("Orders")

plt.title("Footfall vs Orders")

plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["marketing_spend"],
            df["revenue"])

plt.xlabel("Marketing Spend")

plt.ylabel("Revenue")

plt.title("Marketing Spend vs Revenue")

plt.show()

# %%
costs=[

df["cogs"].sum(),

df["rent"].sum(),

df["salaries"].sum(),

df["marketing_spend"].sum(),

df["utilities"].sum()

]

labels=[

"COGS",

"Rent",

"Salaries",

"Marketing",

"Utilities"

]

plt.figure(figsize=(8,6))

plt.pie(costs,
        labels=labels,
        autopct="%1.1f%%")

plt.title("Business Cost Distribution")

plt.show()

# %%
corr=df.select_dtypes(include=np.number).corr()

plt.figure(figsize=(12,10))

plt.imshow(corr,cmap="coolwarm")

plt.colorbar()

plt.xticks(range(len(corr.columns)),
           corr.columns,
           rotation=90)

plt.yticks(range(len(corr.columns)),
           corr.columns)

plt.tight_layout()

plt.show()

# %%
top=df.groupby("outlet_name")["profit"].sum().sort_values().tail(10)

plt.figure(figsize=(10,6))

plt.barh(top.index,
         top.values)

plt.title("Top 10 Profitable Outlets")

plt.show()

# %% [markdown]
# # Business Insights

# %%
print("="*60)
print("BUSINESS INSIGHTS")
print("="*60)

print("• Revenue increased consistently during the observed months.")
print("• Profit margin remained healthy across most outlets.")
print("• Higher customer footfall generally resulted in more orders.")
print("• Marketing spend showed a positive relationship with revenue.")
print("• COGS represented the largest operational expense.")
print("• Premium store formats generated higher profitability.")
print("• South zone outlets contributed significantly to revenue.")
print("• Recommend investing more in high-performing locations and optimizing operating costs.")
# Out:
# ============================================================
# BUSINESS INSIGHTS
# ============================================================
# • Revenue increased consistently during the observed months.
# • Profit margin remained healthy across most outlets.
# • Higher customer footfall generally resulted in more orders.
# • Marketing spend showed a positive relationship with revenue.
# • COGS represented the largest operational expense.
# • Premium store formats generated higher profitability.
# • South zone outlets contributed significantly to revenue.
# • Recommend investing more in high-performing locations and optimizing operating costs.
